# %% [markdown]
# <a href="https://colab.research.google.com/github/upright2003/stable-diffusion-webui-reForge-colab/blob/main/stable_diffusion_webui_reForge_colab%E7%89%88.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 最近编辑日期：2025/09/17

# %%
# !git clone https://github.com/Panchovix/stable-diffusion-webui-reForge.git
# %cd /content/stable-diffusion-webui-reForge

# %%
# @title  必須每次都點
# !git clone https://huggingface.co/embed/negative /content/stable-diffusion-webui-reForge/embeddings/negative
# !git clone https://github.com/Bing-su/adetailer /content/stable-diffusion-webui-reForge/extensions/adetailer

# !git clone https://github.com/zanllp/sd-webui-infinite-image-browsing /content/stable-diffusion-webui-reForge/extensions/sd-webui-infinite-image-browsing
# !git clone https://github.com/picobyte/stable-diffusion-webui-wd14-tagger  /content/stable-diffusion-webui-reForge/extensions/stable-diffusion-webui-wd14-tagger
# !git clone https://github.com/DominikDoom/a1111-sd-webui-tagcomplete.git  /content/stable-diffusion-webui-reForge/extensions/a1111-sd-webui-tagcomplete
# !git clone https://github.com/fkunn1326/openpose-editor /content/stable-diffusion-webui-reForge/extensions/openpose-editor
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/embed/upscale/resolve/main/4x-UltraSharp.pth -d /content/stable-diffusion-webui-reForge/models/ESRGAN -o 4x-UltraSharp.pth

# %%
# @title ControlNet 下載模型 sdxl 需要先执行 launch.py 後才能再执行此处
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lllyasviel/sd_control_collection/resolve/main/diffusers_xl_canny_mid.safetensors -d /content/stable-diffusion-webui-reForge/models/ControlNet -o diffusers_xl_canny_mid.safetensors

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M \
  https://huggingface.co/StableDiffusionVN/XLControlnet/resolve/7e5cf0f681d09ec8325babb7e7fc877d49668c69/t2i-adapter_diffusers_xl_openpose.safetensors \
  -d /content/stable-diffusion-webui-reForge/models/ControlNet \
  -o t2i-adapter_diffusers_xl_openpose.safetensors

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M \
  https://huggingface.co/StableDiffusionVN/XLControlnet/resolve/b435e749a320dc42d1eb6979495019d14e18b90a/t2i-adapter_diffusers_xl_lineart.safetensors \
  -d /content/stable-diffusion-webui-reForge/models/ControlNet \
  -o t2i-adapter_diffusers_xl_lineart.safetensors

# %%
# @title civitai LORA 下載
civitai_models_id = "2017854" # @param {"type":"string"}
filename = "Ani_(Grok)_Illustrious_2.0-XL_v2.safetensors" # @param {"type":"string"}
# !mkdir /content/stable-diffusion-webui-reForge/models/Lora
# !wget -O "/content/stable-diffusion-webui-reForge/models/Lora/{filename}" "https://civitai.com/api/download/models/{civitai_models_id}?token=78e4d44eb6f7d1830fc915b43d513101"

# %%
# @title lora SDXL整合包下載，需要自己上传zip到Google drive 并且取得分享链接
# !mkdir /content/stable-diffusion-webui-reForge/models/Lora
#!gdown xxxxxxxx -O /content/stable-diffusion-webui-reForge/models/Lora/lora_sdxl.zip
#!unzip /content/stable-diffusion-webui-reForge/models/Lora/lora_sdxl.zip -d /content/stable-diffusion-webui-reForge/models/Lora

# @title WAI-NSFW-illustrious-SDXL v15.0 下載
# !sudo apt-get install aria2
#!aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/1761560?token=78e4d44eb6f7d1830fc915b43d513101 -d /content/stable-diffusion-webui-reForge/models/Stable-diffusion -o waiNSFWIllustrious_v140.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/2167369?token=78e4d44eb6f7d1830fc915b43d513101 -d /content/stable-diffusion-webui-reForge/models/Stable-diffusion -o waiNSFWIllustrious_v150.safetensors

# %%
# @title SD1.5 Sweet-mix 2.2 & 2.1 + vae 下載
# !sudo apt-get install aria2
#!aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/datasets/pluseen/sweetMix_v22/resolve/main/sweetMix_v22Flat.safetensors -d /content/stable-diffusion-webui-forge/models/Stable-diffusion -o sweetMix_v22Flat.safetensors
#!wget -O /content/stable-diffusion-webui-forge/models/VAE/blessed2.vae.safetensors  https://huggingface.co/datasets/pluseen/sweetMix_v22/resolve/main/blessed2.vae.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/datasets/pluseen/sweetMix_v21/resolve/main/sweetMix_v21.safetensors -d /content/stable-diffusion-webui-reForge/models/Stable-diffusion -o sweetMix_v21.safetensors
# !wget -O /content/stable-diffusion-webui-reForge/models/VAE/vae-ft-mse-840000-ema-pruned.ckpt  https://huggingface.co/YANGYINGDUO/vae-ft-mse-840000-ema-pruned.ckpt/resolve/main/vae-ft-mse-840000-ema-pruned.ckpt

# %%
# !pip install basicsr

# %%
# @title 执行stable-diffusion-webui-reForge
# !COMMANDLINE_ARGS="--share --disable-safe-unpickle  --theme dark  --opt-sdp-attention --skip-torch-cuda-test" REQS_FILE="requirements_versions.txt" python launch.py
