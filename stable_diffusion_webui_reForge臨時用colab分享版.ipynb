# %% [markdown]
# <a href="https://colab.research.google.com/github/upright2003/stable-diffusion-webui-reForge-colab/blob/main/stable_diffusion_webui_reForge%E8%87%A8%E6%99%82%E7%94%A8colab%E5%88%86%E4%BA%AB%E7%89%88.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 最近编辑日期：2026/09/06  |
# [Github](https://github.com/upright2003/stable-diffusion-webui-reForge-colab)

# %%
# !sudo apt-get update -y
# !sudo apt-get install python3.11 python3.11-dev python3.11-distutils -y
# !sudo update-alternatives --install /usr/bin/python3 python3 /usr/bin/python3.11
# !curl -sS https://bootstrap.pypa.io/get-pip.py | python3.11

# %% [markdown]
# # 安装stable-diffusion-webui-reForge

# %%
# !git clone https://github.com/Panchovix/stable-diffusion-webui-reForge
# %cd /content/stable-diffusion-webui-reForge
# Out:
# Cloning into 'stable-diffusion-webui-reForge'...
# remote: Enumerating objects: 55712, done.
# remote: Total 55712 (delta 0), reused 0 (delta 0), pack-reused 55712 (from 1)
# Receiving objects: 100% (55712/55712), 109.21 MiB | 24.34 MiB/s, done.
# Resolving deltas: 100% (38850/38850), done.
# /content/stable-diffusion-webui-reForge

# %%
# @title  必須每次都點
#!git clone https://huggingface.co/embed/negative /content/stable-diffusion-webui-reForge/embeddings/negative #sd1.5
#!git clone https://github.com/Bing-su/adetailer /content/stable-diffusion-webui-reForge/extensions/adetailer
# !git clone https://github.com/hinablue/sd-forge-adetailer  /content/stable-diffusion-webui-reForge/extensions/sd-forge-adetailer

#!git clone https://github.com/zanllp/sd-webui-infinite-image-browsing /content/stable-diffusion-webui-reForge/extensions/sd-webui-infinite-image-browsing
# !git clone https://github.com/DominikDoom/a1111-sd-webui-tagcomplete.git  /content/stable-diffusion-webui-reForge/extensions/a1111-sd-webui-tagcomplete
#!git clone https://github.com/fkunn1326/openpose-editor /content/stable-diffusion-webui-reForge/extensions/openpose-editor
# !mkdir -p /content/stable-diffusion-webui-reForge/models/ESRGAN

# !wget -q \
https://huggingface.co/embed/upscale/resolve/main/4x-UltraSharp.pth \
-O /content/stable-diffusion-webui-reForge/models/ESRGAN/4x-UltraSharp.pth

# %%
# @title lora SDXL整合包下載
# !mkdir /content/stable-diffusion-webui-reForge/models/Lora
# !gdown 1JipZQ18DJVT8wurJxk1Eh3xndA6d_UjZ -O /content/stable-diffusion-webui-reForge/models/Lora/lora_test.zip
# !unzip /content/stable-diffusion-webui-reForge/models/Lora/lora_test.zip -d /content/stable-diffusion-webui-reForge/models/Lora

# @title WAI-NSFW-illustrious-SDXL v17.0 下載
# !sudo apt-get install aria2
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.red/api/download/models/2883731?token=78e4d44eb6f7d1830fc915b43d513101 -d /content/stable-diffusion-webui-reForge/models/Stable-diffusion -o waiIllustriousSDXL_v170.safetensors

# %%
# @title 一次执行stable-diffusion-webui-reForge ,等gradio網址出來就關閉繼續點下一個
# %cd /content/stable-diffusion-webui-reForge
# !MPLBACKEND=Agg COMMANDLINE_ARGS="--share --disable-safe-unpickle --theme dark --opt-sdp-attention --skip-torch-cuda-test" \
python3.11 launch.py

# %%
# @title 防止預覽圖出錯2
# %%bash
export GRADIO_ANALYTICS_ENABLED=False
export GRADIO_TEMP_DIR=/tmp/gradio
mkdir -p /tmp/gradio

# %%
# @title 二次执行stable-diffusion-webui-reForge
# %cd /content/stable-diffusion-webui-reForge
# !MPLBACKEND=Agg COMMANDLINE_ARGS="--share --disable-safe-unpickle --theme dark --opt-sdp-attention --skip-torch-cuda-test" \
python3.11 launch.py
